# %% [markdown]
# we're scraping to grab job title, date of posting, company, required skills for the job job description
#
# To know the most in demand job we want to have the jobs, with their date of posting. so we grab thsoe posted over  years then we simply check the amount jobs that lead i.e the most jobs demanded for within the last 5 years
#
# for the recommending we want to train the model on the skills as features and the jobs as a target that is required skills needed for a job determins the type of job to e recommended so a user can just input his skills and jobs are recommended for him based on that

# %% [markdown]
# #### WEB SCRAPING

# %%
# first, the required imports
from bs4 import BeautifulSoup
import csv

from datetime import datetime
import requests
import html5lib

# %%
def get_url(position):
    """Generates a url for each position(web developer, etc)"""
    url_template = 'https://ng.indeed.com/jobs?q={}&start=0'
    url = url_template.format(position)
    return url

# %%
url = get_url('Web developer')
url
# Out:
# 'https://ng.indeed.com/jobs?q=Web developer&start=0'

# %%
#Extracting the raw html
# Access the url with the request object
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# Scrape the web page content
web_page = response.text
# Create a soup object(sl_soup) for parsing the webpage using html parser
sl_soup = BeautifulSoup(web_page, 'html.parser')

# %%
cards = sl_soup.findAll('div', 'cardOutline' )
len(cards)
# Out:
# 15

# %%
#Prototype the extraction of a single record/card
card = cards[0]

# %%
atag_span = card.h2.a.span

# %%
job_title = atag_span.get('title')

# %%
# closing the response object
response.close()

# %%
# To view the content of the soup object
sl_soup.contents
# Out:
# ['html',
#  '\n',
#  <html dir="ltr" lang="en">
#  <head>
#  <script defer="" src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/ea1c9c9/en_NG.min.js"></script>
#  <script></script>
#  <script crossorigin="anonymous" defer="" src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/e2c6e3a37b6515e0849a/scripts/homepage.es6.js" type="module"></script>
#  <script crossorigin="anonymous" defer="" nomodule="" src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/49e517482a9e8d3bf695/scripts/homepage.js"></script>
#  <meta content="With Indeed, you can search millions of jobs online to find the next step in your career. With tools for job search, resumes, company reviews and more, were with you every step of the way." name="description"/>
#  <meta content="job search, Indeed, jobs, search engine for jobs, job search engine, job listings, search jobs, career, employment, work, find jobs, rss jobs feed xml " name="keywords"/>
#  <meta charset="utf-8"/>
# ...

# %%
# Using pretify to view the content in a better format
print(sl_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <script defer="" src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/ea1c9c9/en_NG.min.js">
#   </script>
#   <script>
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/e2c6e3a37b6515e0849a/scripts/homepage.es6.js" type="module">
#   </script>
#   <script crossorigin="anonymous" defer="" nomodule="" src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/49e517482a9e8d3bf695/scripts/homepage.js">
#   </script>
#   <meta content="With Indeed, you can search millions of jobs online to find the next step in your career. With tools for job search, resumes, company reviews and more, were with you every step of the way." name="description"/>
#   <meta content="job search, Indeed, jobs, search engine for jobs, job search engine, job listings, search jobs, career, employment, work, find jobs, rss jobs feed xml " name="keywords"/>
#   <meta charset="utf-8"/>
# ...

# %%
# To view the head and title of the page (the soup object) with the head and title methods
print(sl_soup.head)
# Out:
# <head>
# <script defer="" src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/ea1c9c9/en_NG.min.js"></script>
# <script></script>
# <script crossorigin="anonymous" defer="" src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/e2c6e3a37b6515e0849a/scripts/homepage.es6.js" type="module"></script>
# <script crossorigin="anonymous" defer="" nomodule="" src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/49e517482a9e8d3bf695/scripts/homepage.js"></script>
# <meta content="With Indeed, you can search millions of jobs online to find the next step in your career. With tools for job search, resumes, company reviews and more, were with you every step of the way." name="description"/>
# <meta content="job search, Indeed, jobs, search engine for jobs, job search engine, job listings, search jobs, career, employment, work, find jobs, rss jobs feed xml " name="keywords"/>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# ...

# %%
print(sl_soup.title)
# Out:
# <title>Job Search | Indeed</title>

# %%
for jobs in sl_soup.findAll('jobs'):
    print(jobs)
